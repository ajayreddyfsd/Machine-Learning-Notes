# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, auc, roc_auc_score

# Load the heart disease dataset (replace filename if needed)
df = pd.read_csv('./data/heart-disease.csv')

# Separate features (X) and target (y)
# 'target' should be the column with 0 (no disease) or 1 (disease)
X = df.drop('target', axis=1)  # All columns except 'target'
y = df['target']              # The 'target' column is the label

# Split the dataset into training (80%) and testing (20%)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2
)

# Create the Random Forest classifier
model = RandomForestClassifier(n_estimators=100)

# Train the model using training data
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# evaluating the model

model.score(X_test, y_test)
# Out:
# 0.7377049180327869

# %%
# performing cross validation

from sklearn.model_selection import cross_val_score
cross_val_scores = cross_val_score(model, X, y, cv=10)
cross_val_scores
# Out:
# array([0.90322581, 0.83870968, 0.87096774, 0.93333333, 0.83333333,
#        0.83333333, 0.76666667, 0.83333333, 0.73333333, 0.73333333])

# %%
# average of all cross validated scores

np.mean(cross_val_scores)
# Out:
# np.float64(0.8279569892473118)
